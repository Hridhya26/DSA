# %%
import seaborn as sns
data = sns.load_dataset('titanic')
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder

# %%
df = pd.DataFrame(data)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df1 = df.drop(['embarked','who','adult_male','alive','alone'],axis=1)
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare   class deck  \
# 0           0       3    male  22.0      1      0   7.2500   Third  NaN
# 1           1       1  female  38.0      1      0  71.2833   First    C
# 2           1       3  female  26.0      0      0   7.9250   Third  NaN
# 3           1       1  female  35.0      1      0  53.1000   First    C
# 4           0       3    male  35.0      0      0   8.0500   Third  NaN
# ..        ...     ...     ...   ...    ...    ...      ...     ...  ...
# 886         0       2    male  27.0      0      0  13.0000  Second  NaN
# 887         1       1  female  19.0      0      0  30.0000   First    B
# 888         0       3  female   NaN      1      2  23.4500   Third  NaN
# 889         1       1    male  26.0      0      0  30.0000   First    C
# 890         0       3    male  32.0      0      0   7.7500   Third  NaN
#
#      embark_town
# 0    Southampton
# 1      Cherbourg
# 2    Southampton
# 3    Southampton
# ...

# %%
print(df1['deck'].value_counts())
# Out:
# deck
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# Name: count, dtype: int64

# %%
df1.dropna(subset=["deck"],inplace=True)
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  class deck  \
# 1           1       1  female  38.0      1      0  71.2833  First    C
# 3           1       1  female  35.0      1      0  53.1000  First    C
# 6           0       1    male  54.0      0      0  51.8625  First    E
# 10          1       3  female   4.0      1      1  16.7000  Third    G
# 11          1       1  female  58.0      0      0  26.5500  First    C
# ..        ...     ...     ...   ...    ...    ...      ...    ...  ...
# 871         1       1  female  47.0      1      1  52.5542  First    D
# 872         0       1    male  33.0      0      0   5.0000  First    B
# 879         1       1  female  56.0      0      1  83.1583  First    C
# 887         1       1  female  19.0      0      0  30.0000  First    B
# 889         1       1    male  26.0      0      0  30.0000  First    C
#
#      embark_town
# 1      Cherbourg
# 3    Southampton
# 6    Southampton
# 10   Southampton
# 11   Southampton
# ...

# %%
label_enc = LabelEncoder()
df1['embark_town_encoded'] = label_enc.fit_transform(df1['embark_town'])
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  class deck  \
# 1           1       1  female  38.0      1      0  71.2833  First    C
# 3           1       1  female  35.0      1      0  53.1000  First    C
# 6           0       1    male  54.0      0      0  51.8625  First    E
# 10          1       3  female   4.0      1      1  16.7000  Third    G
# 11          1       1  female  58.0      0      0  26.5500  First    C
# ..        ...     ...     ...   ...    ...    ...      ...    ...  ...
# 871         1       1  female  47.0      1      1  52.5542  First    D
# 872         0       1    male  33.0      0      0   5.0000  First    B
# 879         1       1  female  56.0      0      1  83.1583  First    C
# 887         1       1  female  19.0      0      0  30.0000  First    B
# 889         1       1    male  26.0      0      0  30.0000  First    C
#
#      embark_town  embark_town_encoded
# 1      Cherbourg                    0
# ...

# %%
label_enc = LabelEncoder()
df1['sex_encoded'] = label_enc.fit_transform(df1['sex'])
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  class deck  \
# 1           1       1  female  38.0      1      0  71.2833  First    C
# 3           1       1  female  35.0      1      0  53.1000  First    C
# 6           0       1    male  54.0      0      0  51.8625  First    E
# 10          1       3  female   4.0      1      1  16.7000  Third    G
# 11          1       1  female  58.0      0      0  26.5500  First    C
# ..        ...     ...     ...   ...    ...    ...      ...    ...  ...
# 871         1       1  female  47.0      1      1  52.5542  First    D
# 872         0       1    male  33.0      0      0   5.0000  First    B
# 879         1       1  female  56.0      0      1  83.1583  First    C
# 887         1       1  female  19.0      0      0  30.0000  First    B
# 889         1       1    male  26.0      0      0  30.0000  First    C
#
#      embark_town  embark_town_encoded  sex_encoded
# 1      Cherbourg                    0            0
# ...

# %%
ordinal_enc = OrdinalEncoder()
df1['class_encoded'] = ordinal_enc.fit_transform(df1[['class']])
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  class deck  \
# 1           1       1  female  38.0      1      0  71.2833  First    C
# 3           1       1  female  35.0      1      0  53.1000  First    C
# 6           0       1    male  54.0      0      0  51.8625  First    E
# 10          1       3  female   4.0      1      1  16.7000  Third    G
# 11          1       1  female  58.0      0      0  26.5500  First    C
# ..        ...     ...     ...   ...    ...    ...      ...    ...  ...
# 871         1       1  female  47.0      1      1  52.5542  First    D
# 872         0       1    male  33.0      0      0   5.0000  First    B
# 879         1       1  female  56.0      0      1  83.1583  First    C
# 887         1       1  female  19.0      0      0  30.0000  First    B
# 889         1       1    male  26.0      0      0  30.0000  First    C
#
#      embark_town  embark_town_encoded  sex_encoded  class_encoded
# ...

# %%
embark_town_onehot = pd.get_dummies(df1,columns=['embark_town'],prefix='emb_town',dtype=int)
embark_town_onehot
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  class deck  \
# 1           1       1  female  38.0      1      0  71.2833  First    C
# 3           1       1  female  35.0      1      0  53.1000  First    C
# 6           0       1    male  54.0      0      0  51.8625  First    E
# 10          1       3  female   4.0      1      1  16.7000  Third    G
# 11          1       1  female  58.0      0      0  26.5500  First    C
# ..        ...     ...     ...   ...    ...    ...      ...    ...  ...
# 871         1       1  female  47.0      1      1  52.5542  First    D
# 872         0       1    male  33.0      0      0   5.0000  First    B
# 879         1       1  female  56.0      0      1  83.1583  First    C
# 887         1       1  female  19.0      0      0  30.0000  First    B
# 889         1       1    male  26.0      0      0  30.0000  First    C
#
#      embark_town_encoded  sex_encoded  class_encoded  emb_town_Cherbourg  \
# ...

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
std_scaler = StandardScaler()
df1['fare_std_scaled'] = std_scaler.fit_transform(df1[['fare']])
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  class deck  \
# 1           1       1  female  38.0      1      0  71.2833  First    C
# 3           1       1  female  35.0      1      0  53.1000  First    C
# 6           0       1    male  54.0      0      0  51.8625  First    E
# 10          1       3  female   4.0      1      1  16.7000  Third    G
# 11          1       1  female  58.0      0      0  26.5500  First    C
# ..        ...     ...     ...   ...    ...    ...      ...    ...  ...
# 871         1       1  female  47.0      1      1  52.5542  First    D
# 872         0       1    male  33.0      0      0   5.0000  First    B
# 879         1       1  female  56.0      0      1  83.1583  First    C
# 887         1       1  female  19.0      0      0  30.0000  First    B
# 889         1       1    male  26.0      0      0  30.0000  First    C
#
#      embark_town  embark_town_encoded  sex_encoded  class_encoded  \
# ...

# %%
df1['fare_std_scaled'].mean()
# Out:
# -3.500210520985715e-17

# %%
df1['fare_std_scaled'].median()
# Out:
# -0.28115302631005057

# %%
df1['fare_std_scaled'].std()
# Out:
# 1.0024721916589527

# %%
min_scaler = MinMaxScaler(feature_range=(0,1))
df1['fare_min_scaled'] = min_scaler.fit_transform(df1[['fare']])
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  class deck  \
# 1           1       1  female  38.0      1      0  71.2833  First    C
# 3           1       1  female  35.0      1      0  53.1000  First    C
# 6           0       1    male  54.0      0      0  51.8625  First    E
# 10          1       3  female   4.0      1      1  16.7000  Third    G
# 11          1       1  female  58.0      0      0  26.5500  First    C
# ..        ...     ...     ...   ...    ...    ...      ...    ...  ...
# 871         1       1  female  47.0      1      1  52.5542  First    D
# 872         0       1    male  33.0      0      0   5.0000  First    B
# 879         1       1  female  56.0      0      1  83.1583  First    C
# 887         1       1  female  19.0      0      0  30.0000  First    B
# 889         1       1    male  26.0      0      0  30.0000  First    C
#
#      embark_town  embark_town_encoded  sex_encoded  class_encoded  \
# ...

# %%
numerical_columns = ['survived','pclass','sibsp','parch']
scaled_df = std_scaler.fit_transform(df1[numerical_columns])
df1[numerical_columns] = scaled_df
df1[numerical_columns]
# Out:
#      survived    pclass     sibsp     parch
# 1    0.701888 -0.374766  0.886172 -0.601132
# 3    0.701888 -0.374766  0.886172 -0.601132
# 6   -1.424728 -0.374766 -0.705801 -0.601132
# 10   0.701888  3.429107  0.886172  0.769989
# 11   0.701888 -0.374766 -0.705801 -0.601132
# ..        ...       ...       ...       ...
# 871  0.701888 -0.374766  0.886172  0.769989
# 872 -1.424728 -0.374766 -0.705801 -0.601132
# 879  0.701888 -0.374766 -0.705801  0.769989
# 887  0.701888 -0.374766 -0.705801 -0.601132
# 889  0.701888 -0.374766 -0.705801 -0.601132
#
# [203 rows x 4 columns]

# %%
min_scaler = MinMaxScaler()
df1[numerical_columns] = min_scaler.fit_transform(df1[numerical_columns])
df1[numerical_columns]
# Out:
#      survived  pclass     sibsp  parch
# 1         1.0     0.0  0.333333   0.00
# 3         1.0     0.0  0.333333   0.00
# 6         0.0     0.0  0.000000   0.00
# 10        1.0     1.0  0.333333   0.25
# 11        1.0     0.0  0.000000   0.00
# ..        ...     ...       ...    ...
# 871       1.0     0.0  0.333333   0.25
# 872       0.0     0.0  0.000000   0.00
# 879       1.0     0.0  0.000000   0.25
# 887       1.0     0.0  0.000000   0.00
# 889       1.0     0.0  0.000000   0.00
#
# [203 rows x 4 columns]
