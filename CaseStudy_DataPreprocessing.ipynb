# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\user\\Downloads\\House_Pricing.csv')
df
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %% [markdown]
# # Data Overview

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        2124 non-null   object
# ...

# %%
df.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21604.000000        2.160400e+04  21613.000000   21613.000000
# mean           2079.931772        1.510776e+04      1.494309       7.623467
# std             918.487597        4.142827e+04      0.539989       1.105439
# ...

# %%
df.dtypes
# Out:
# ID                                             int64
# Date House was Sold                           object
# Sale Price                                   float64
# No of Bedrooms                                 int64
# No of Bathrooms                              float64
# Flat Area (in Sqft)                          float64
# Lot Area (in Sqft)                           float64
# No of Floors                                 float64
# Waterfront View                               object
# No of Times Visited                           object
# Condition of the House                        object
# Overall Grade                                  int64
# Area of the House from Basement (in Sqft)    float64
# Basement Area (in Sqft)                        int64
# Age of House (in Years)                        int64
# Renovated Year                                 int64
# Zipcode                                      float64
# Latitude                                     float64
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.size
# Out:
# 453873

# %%
df.isna().sum()
# Out:
# ID                                               0
# Date House was Sold                              0
# Sale Price                                       4
# No of Bedrooms                                   0
# No of Bathrooms                                  4
# Flat Area (in Sqft)                              9
# Lot Area (in Sqft)                               9
# No of Floors                                     0
# Waterfront View                                  0
# No of Times Visited                          19489
# Condition of the House                           0
# Overall Grade                                    0
# Area of the House from Basement (in Sqft)        3
# Basement Area (in Sqft)                          0
# Age of House (in Years)                          0
# Renovated Year                                   0
# Zipcode                                          1
# Latitude                                         1
# ...

# %% [markdown]
# # Duplicate Removal

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Handle Missing Values

# %%
df = df.drop('No of Times Visited',axis=1)
df
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
df.isna().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   4
# No of Bedrooms                               0
# No of Bathrooms                              4
# Flat Area (in Sqft)                          9
# Lot Area (in Sqft)                           9
# No of Floors                                 0
# Waterfront View                              0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    3
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      1
# Latitude                                     1
# Longitude                                    1
# Living Area after Renovation (in Sqft)       1
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
num_df = df.select_dtypes(include="number")
cat_df = df.select_dtypes(include="object")
print("Numerical columns are")
num_cols = num_df.columns.tolist()
print(num_cols)

cat_cols = cat_df.columns.tolist()
print("Categorical columns are")
print(cat_cols)
# Out:
# Numerical columns are
# ['ID', 'Sale Price', 'No of Bedrooms', 'No of Bathrooms', 'Flat Area (in Sqft)', 'Lot Area (in Sqft)', 'No of Floors', 'Overall Grade', 'Area of the House from Basement (in Sqft)', 'Basement Area (in Sqft)', 'Age of House (in Years)', 'Renovated Year', 'Zipcode', 'Latitude', 'Longitude', 'Living Area after Renovation (in Sqft)', 'Lot Area after Renovation (in Sqft)']
# Categorical columns are
# ['Date House was Sold', 'Waterfront View', 'Condition of the House']

# %%
import matplotlib.pyplot as plt

# %%
for col in num_cols:
    plt.hist(num_df[col])
    plt.xlabel(col)
    plt.ylabel('count')
    plt.show()

# %%
for col in num_cols:
    num_df[col] = num_df[col].fillna(num_df[col].median())

# %%
num_df.isna().sum()
# Out:
# ID                                           0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# No of Floors                                 0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       0
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
df = pd.concat([num_df,cat_df],axis=1)

# %%
df.isna().sum()
# Out:
# ID                                           0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# No of Floors                                 0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       0
# Lot Area after Renovation (in Sqft)          0
# Date House was Sold                          0
# Waterfront View                              0
# Condition of the House                       0
# dtype: int64

# %% [markdown]
# # Oulier Handling

# %%
plt.boxplot(num_df)
plt.show()

# %%
def remove_outliers(df,column_name):
    q1 = df[column_name].quantile(0.25)
    q3 = df[column_name].quantile(0.75)
    iqr = q3-q1
    upper_bound = q3+1.5*iqr
    lower_bound = q1-1.5*iqr
    df[column_name] = df[column_name].clip(upper=upper_bound)
    df[column_name] = df[column_name].clip(lower=lower_bound)
    return df[column_name]

# %%
for col in num_cols:
    num_df[col] = remove_outliers(num_df,col)

# %%
num_df.boxplot()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Encoding

# %%
df.dtypes
# Out:
# ID                                             int64
# Sale Price                                   float64
# No of Bedrooms                                 int64
# No of Bathrooms                              float64
# Flat Area (in Sqft)                          float64
# Lot Area (in Sqft)                           float64
# No of Floors                                 float64
# Overall Grade                                  int64
# Area of the House from Basement (in Sqft)    float64
# Basement Area (in Sqft)                        int64
# Age of House (in Years)                        int64
# Renovated Year                                 int64
# Zipcode                                      float64
# Latitude                                     float64
# Longitude                                    float64
# Living Area after Renovation (in Sqft)       float64
# Lot Area after Renovation (in Sqft)            int64
# Date House was Sold                           object
# ...

# %%
df
# Out:
#                ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0      7129300520    221900.0               3             1.00
# 1      6414100192    538000.0               3             2.25
# 2      5631500400    180000.0               2             1.00
# 3      2487200875    604000.0               4             3.00
# 4      1954400510    510000.0               3             2.00
# ...           ...         ...             ...              ...
# 21608   263000018    360000.0               3             2.50
# 21609  6600060120    400000.0               4             2.50
# 21610  1523300141    402101.0               2             0.75
# 21611   291310100    400000.0               3             2.50
# 21612  1523300157    325000.0               2             0.75
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# 0                   1180.0              5650.0           1.0              7
# ...

# %%
df['Waterfront View'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Condition of the House'].unique()
# Out:
# array(['Fair', 'Excellent', 'Good', 'Bad', 'Okay'], dtype=object)

# %%
df['Date House was Sold'].unique()
# Out:
# array(['14 October 2017', '14 December 2017', '15 February 2016',
#        '14 May 2017', '14 June 2017', '15 January 2016', '15 April 2016',
#        '15 March 2016', '14 July 2017', '14 August 2017',
#        '14 November 2017', '14 September 2017', '15 May 2016'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder

# %%
label_enc = LabelEncoder()
df['Waterfront_encoded'] = label_enc.fit_transform(df['Waterfront View'])
df
# Out:
#                ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0      7129300520    221900.0               3             1.00
# 1      6414100192    538000.0               3             2.25
# 2      5631500400    180000.0               2             1.00
# 3      2487200875    604000.0               4             3.00
# 4      1954400510    510000.0               3             2.00
# ...           ...         ...             ...              ...
# 21608   263000018    360000.0               3             2.50
# 21609  6600060120    400000.0               4             2.50
# 21610  1523300141    402101.0               2             0.75
# 21611   291310100    400000.0               3             2.50
# 21612  1523300157    325000.0               2             0.75
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# 0                   1180.0              5650.0           1.0              7
# ...

# %%
condition_order = ['Excellent','Good','Fair','Okay','Bad']
ordinal_enc = OrdinalEncoder(categories=[condition_order])
df['Condition of the House'] = ordinal_enc.fit_transform(df[['Condition of the House']])
df
# Out:
#                ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0      7129300520    221900.0               3             1.00
# 1      6414100192    538000.0               3             2.25
# 2      5631500400    180000.0               2             1.00
# 3      2487200875    604000.0               4             3.00
# 4      1954400510    510000.0               3             2.00
# ...           ...         ...             ...              ...
# 21608   263000018    360000.0               3             2.50
# 21609  6600060120    400000.0               4             2.50
# 21610  1523300141    402101.0               2             0.75
# 21611   291310100    400000.0               3             2.50
# 21612  1523300157    325000.0               2             0.75
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# 0                   1180.0              5650.0           1.0              7
# ...

# %%
Waterfront_onehot = pd.get_dummies(df,columns=['Waterfront View'],prefix = 'Wat',dtype=int)
Waterfront_onehot
# Out:
#                ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0      7129300520    221900.0               3             1.00
# 1      6414100192    538000.0               3             2.25
# 2      5631500400    180000.0               2             1.00
# 3      2487200875    604000.0               4             3.00
# 4      1954400510    510000.0               3             2.00
# ...           ...         ...             ...              ...
# 21608   263000018    360000.0               3             2.50
# 21609  6600060120    400000.0               4             2.50
# 21610  1523300141    402101.0               2             0.75
# 21611   291310100    400000.0               3             2.50
# 21612  1523300157    325000.0               2             0.75
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# 0                   1180.0              5650.0           1.0              7
# ...

# %%
df = pd.concat([df,Waterfront_onehot],axis=1)
df
# Out:
#                ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0      7129300520    221900.0               3             1.00
# 1      6414100192    538000.0               3             2.25
# 2      5631500400    180000.0               2             1.00
# 3      2487200875    604000.0               4             3.00
# 4      1954400510    510000.0               3             2.00
# ...           ...         ...             ...              ...
# 21608   263000018    360000.0               3             2.50
# 21609  6600060120    400000.0               4             2.50
# 21610  1523300141    402101.0               2             0.75
# 21611   291310100    400000.0               3             2.50
# 21612  1523300157    325000.0               2             0.75
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# 0                   1180.0              5650.0           1.0              7
# ...

# %%
df = df.drop("Date House was Sold",axis=1)
df
# Out:
#                ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0      7129300520    221900.0               3             1.00
# 1      6414100192    538000.0               3             2.25
# 2      5631500400    180000.0               2             1.00
# 3      2487200875    604000.0               4             3.00
# 4      1954400510    510000.0               3             2.00
# ...           ...         ...             ...              ...
# 21608   263000018    360000.0               3             2.50
# 21609  6600060120    400000.0               4             2.50
# 21610  1523300141    402101.0               2             0.75
# 21611   291310100    400000.0               3             2.50
# 21612  1523300157    325000.0               2             0.75
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# 0                   1180.0              5650.0           1.0              7
# ...

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
#df.select_dtypes(include=['number'])

# %%
df.drop("Sale Price",axis=1)
# Out:
#                ID  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0      7129300520               3             1.00               1180.0
# 1      6414100192               3             2.25               2570.0
# 2      5631500400               2             1.00                770.0
# 3      2487200875               4             3.00               1960.0
# 4      1954400510               3             2.00               1680.0
# ...           ...             ...              ...                  ...
# 21608   263000018               3             2.50               1530.0
# 21609  6600060120               4             2.50               2310.0
# 21610  1523300141               2             0.75               1020.0
# 21611   291310100               3             2.50               1600.0
# 21612  1523300157               2             0.75               1020.0
#
#        Lot Area (in Sqft)  No of Floors  Overall Grade  \
# ...

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
min_scaler = MinMaxScaler(feature_range=(0,1))
df['Flat Area (in Sqft)'] = min_scaler.fit_transform(df[['Flat Area (in Sqft)']])
df
# Out:
#                ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0      7129300520    221900.0               3             1.00
# 1      6414100192    538000.0               3             2.25
# 2      5631500400    180000.0               2             1.00
# 3      2487200875    604000.0               4             3.00
# 4      1954400510    510000.0               3             2.00
# ...           ...         ...             ...              ...
# 21608   263000018    360000.0               3             2.50
# 21609  6600060120    400000.0               4             2.50
# 21610  1523300141    402101.0               2             0.75
# 21611   291310100    400000.0               3             2.50
# 21612  1523300157    325000.0               2             0.75
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# 0                 0.067170              5650.0           1.0              7
# ...

# %%
std_scaler = StandardScaler()
df['Lot Area (in Sqft)'] = std_scaler.fit_transform(df[['Lot Area (in Sqft)']])
df
# Out:
#                ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0      7129300520    221900.0               3             1.00
# 1      6414100192    538000.0               3             2.25
# 2      5631500400    180000.0               2             1.00
# 3      2487200875    604000.0               4             3.00
# 4      1954400510    510000.0               3             2.00
# ...           ...         ...             ...              ...
# 21608   263000018    360000.0               3             2.50
# 21609  6600060120    400000.0               4             2.50
# 21610  1523300141    402101.0               2             0.75
# 21611   291310100    400000.0               3             2.50
# 21612  1523300157    325000.0               2             0.75
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# 0                 0.067170           -0.228268           1.0              7
# ...

# %% [markdown]
# ## Train-Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
y = df["Sale Price"]
X = df.drop("Sale Price",axis=1)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
#                ID  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 15879  8807300130               3             1.00             0.046792
# 11550  2896000510               4             2.50             0.138113
# 14584  9277200180               3             1.00             0.084528
# 5173   5205000250               3             2.50             0.153208
# 8202   9264930770               5             3.50             0.201509
# ...           ...             ...              ...                  ...
# 20130  3336500190               3             2.50             0.104151
# 20610  6056100312               3             2.50             0.098868
# 19602  7203150330               4             2.50             0.164528
# 2726   8965400390               5             2.25             0.209057
# 13031  1843130210               3             2.50             0.123019
#
#        Lot Area (in Sqft)  No of Floors  Overall Grade  \
# ...

# %%
y_train
# Out:
#        Sale Price  Sale Price
# 15879    330000.0    330000.0
# 11550    490000.0    490000.0
# 14584    410000.0    410000.0
# 5173     308000.0    308000.0
# 8202     389500.0    389500.0
# ...           ...         ...
# 20130    252000.0    252000.0
# 20610    395000.0    395000.0
# 19602    669000.0    669000.0
# 2726     749999.0    749999.0
# 13031    266950.0    266950.0
#
# [17290 rows x 2 columns]

# %%
X_test
# Out:
#                ID  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 9233   4237901075               4             2.50             0.144906
# 18566  7893203770               3             1.00             0.070189
# 12835  8961800035               2             1.00             0.067925
# 20157  1102000514               5             3.50             0.234717
# 16180  9285800585               3             2.00             0.133585
# ...           ...             ...              ...                  ...
# 12902  2473411210               4             1.75             0.103396
# 14074  2561360210               3             2.25             0.135849
# 18326  7831800110               3             1.00             0.069434
# 11637  2730000270               3             1.00             0.046038
# 16398  7893206305               3             1.50             0.136604
#
#        Lot Area (in Sqft)  No of Floors  Overall Grade  \
# ...

# %%
y_test
# Out:
#        Sale Price  Sale Price
# 9233     733000.0    733000.0
# 18566    196000.0    196000.0
# 12835    229000.0    229000.0
# 20157    970000.0    970000.0
# 16180    460000.0    460000.0
# ...           ...         ...
# 12902    374950.0    374950.0
# 14074    562100.0    562100.0
# 18326    215000.0    215000.0
# 11637    178500.0    178500.0
# 16398    245000.0    245000.0
#
# [4323 rows x 2 columns]
